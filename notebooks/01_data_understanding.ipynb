# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 120)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       4 pd.set_option("display.max_columns", None)
#
# File d:\PROJECTS\Used-Car-Price-Prediction-Seller-Decision-Intelligence-System\venv\Lib\site-packages\pandas\__init__.py:61
#      58 # let init-time option registration happen
#      59 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 61 from pandas.core.api import (
#      62     # dtype
#      63     ArrowDtype,
#      64     Int8Dtype,
#      65     Int16Dtype,
#      66     Int32Dtype,
#      67     Int64Dtype,
#      68     UInt8Dtype,
#      69     UInt16Dtype,
#      70     UInt32Dtype,
#      71     UInt64Dtype,
#      72     Float32Dtype,
#      73     Float64Dtype,
#      74     CategoricalDtype,
#      75     PeriodDtype,
# ...

# %%
DATA_PATH = "../data/raw/used_cars.csv"

df = pd.read_csv(DATA_PATH)
df.head()

# %%
print("Hello")
# Out:
# Hello
